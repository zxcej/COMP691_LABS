# %% [markdown]
# # Question 1
#
# ### Exercise 1.(b)

# %%
from PIL import Image
import numpy as np

# Open the image
im = Image.open("R.png")

#Convert to tensor
im = np.array(im)

print (im.shape)
for line in im:
    print(line)
# Out:
# (980, 980, 2)
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
#  [255   0]
#  ...
#  [255   0]
#  [255   0]
#  [255   0]]
# [[255   0]
#  [255   0]
# ...
